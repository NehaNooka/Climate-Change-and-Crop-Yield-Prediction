# %%
import pandas as pd

# %%
Crop_Land_Nutrient_Balance_df= pd.read_csv("Crop_Land_Nutrient_Balance.csv")
Crop_Land_Nutrient_Balance_df.drop(['Domain','Domain Code', 'Area Code (M49)', 'Element Code','Item Code', 'Year Code', 'Note'], axis=1,inplace=True)
Crop_Land_Nutrient_Balance_df.rename(columns={'Element': 'Nutrients', 'Item': 'Nutrients_type', 'Value': 'Nutrients_Value',  'Unit': 'Nutrients_Unit', 'Flag': 'Nutrients_Flag', 'Flag Description': 'Nutrients_Flag_Description'}, inplace=True)
Crop_Land_Nutrient_Balance_df = Crop_Land_Nutrient_Balance_df[Crop_Land_Nutrient_Balance_df['Nutrients'].isin(['Cropland nitrogen', 'Cropland phosphorus', 'Cropland potassium'])]
Crop_Land_Nutrient_Balance_df = Crop_Land_Nutrient_Balance_df[Crop_Land_Nutrient_Balance_df['Year'].between(2000, 2021)]
# print(Crop_Land_Nutrient_Balance_df['Nutrients'].unique())
Crop_Land_Nutrient_Balance_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-06c0d331c1b8> in <cell line: 1>()
# ----> 1 Crop_Land_Nutrient_Balance_df= pd.read_csv("Crop_Land_Nutrient_Balance.csv")
#       2 Crop_Land_Nutrient_Balance_df.drop(['Domain','Domain Code', 'Area Code (M49)', 'Element Code','Item Code', 'Year Code', 'Note'], axis=1,inplace=True)
#       3 Crop_Land_Nutrient_Balance_df.rename(columns={'Element': 'Nutrients', 'Item': 'Nutrients_type', 'Value': 'Nutrients_Value',  'Unit': 'Nutrients_Unit', 'Flag': 'Nutrients_Flag', 'Flag Description': 'Nutrients_Flag_Description'}, inplace=True)
#       4 Crop_Land_Nutrient_Balance_df = Crop_Land_Nutrient_Balance_df[Crop_Land_Nutrient_Balance_df['Nutrients'].isin(['Cropland nitrogen', 'Cropland phosphorus', 'Cropland potassium'])]
#       5 Crop_Land_Nutrient_Balance_df = Crop_Land_Nutrient_Balance_df[Crop_Land_Nutrient_Balance_df['Year'].between(2000, 2021)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Crop_Land_Nutrient_Balance.csv'

# %%
Crop_Production_df= pd.read_csv("Crop_Production.csv")
Crop_Production_df.drop(['Domain','Domain Code', 'Area Code (M49)', 'Element Code','Item Code (CPC)', 'Year Code' , 'Note'], axis=1,inplace=True)
Crop_Production_df.rename(columns={'Element': 'Prod_type', 'Value': 'Prod_Value', 'Item': 'Crop_Name', 'Value': 'Crop_Production_Value',  'Unit': 'Crop_Production_Unit', 'Flag': 'Crop_Production_Flag', 'Flag Description': 'Crop_Production_Flag_Description'}, inplace=True)
Crop_Production_df = Crop_Production_df[Crop_Production_df['Year'].between(2000, 2021)]
# Crop_Production_df = Crop_Land_Nutrient_Balance_df[Crop_Land_Nutrient_Balance_df['Nutrients'].isin(['Cropland nitrogen', 'Cropland phosphorus', 'Cropland potassium'])]
# print(Crop_Land_Nutrient_Balance_df['Nutrients'].unique())
Crop_Production_df
# Out:
#             Area       Prod_type   Crop_Name  Year Crop_Production_Unit  \
# 117   Bangladesh  Area harvested      Barley  2000                   ha
# 118   Bangladesh           Yield      Barley  2000             100 g/ha
# 119   Bangladesh      Production      Barley  2000                    t
# 120   Bangladesh  Area harvested      Barley  2001                   ha
# 121   Bangladesh           Yield      Barley  2001             100 g/ha
# ...          ...             ...         ...   ...                  ...
# 2848    Viet Nam           Yield  Sugar cane  2020             100 g/ha
# 2849    Viet Nam      Production  Sugar cane  2020                    t
# 2850    Viet Nam  Area harvested  Sugar cane  2021                   ha
# 2851    Viet Nam           Yield  Sugar cane  2021             100 g/ha
# 2852    Viet Nam      Production  Sugar cane  2021                    t
#
#       Crop_Production_Value Crop_Production_Flag  \
# 117                 6880.00                    A
# 118                 7267.00                    A
# 119                 5000.00                    A
# 120                 5668.00                    A
# 121                 7057.00                    A
# ...                     ...                  ...
# 2848              622030.00                    A
# 2849            11534588.71                    A
# 2850              165919.00                    A
# 2851              647355.00                    A
# 2852            10740873.28                    A
#
#      Crop_Production_Flag_Description
# 117                   Official figure
# 118                   Official figure
# 119                   Official figure
# 120                   Official figure
# 121                   Official figure
# ...                               ...
# 2848                  Official figure
# 2849                  Official figure
# 2850                  Official figure
# 2851                  Official figure
# 2852                  Official figure
#
# [1056 rows x 8 columns]

# %%
Temperature_Change_On_Land_df= pd.read_csv("Temperature_Change_On_Land.csv")
Temperature_Change_On_Land_df.drop(['Domain','Domain Code', 'Area Code (M49)', 'Element Code', 'Months Code', 'Year Code'],  axis=1,inplace=True)
Temperature_Change_On_Land_df.rename(columns={'Element': 'Temp_Change', 'Value': 'TMP_Value',  'Unit': 'TMP_Unit', 'Flag': 'TMP_Flag', 'Flag Description': 'TMP_Description'}, inplace=True)
Temperature_Change_On_Land_df = Temperature_Change_On_Land_df[Temperature_Change_On_Land_df['Year'].between(2000, 2021)]
Temperature_Change_On_Land_df = Temperature_Change_On_Land_df[Temperature_Change_On_Land_df['Months'].isin(['January','February','March' ,'April' ,'May' ,'June','July','August','September','October','November','December'])]
# print(Temperature_Change_On_Land_df['Months'].unique())
Temperature_Change_On_Land_df
# Out:
#             Area         Temp_Change    Months  Year TMP_Unit  TMP_Value  \
# 39    Bangladesh  Temperature change   January  2000       °c      0.532
# 40    Bangladesh  Temperature change   January  2001       °c     -0.388
# 41    Bangladesh  Temperature change   January  2002       °c      0.832
# 42    Bangladesh  Temperature change   January  2003       °c     -1.236
# 43    Bangladesh  Temperature change   January  2004       °c     -0.055
# ...          ...                 ...       ...   ...      ...        ...
# 9914    Viet Nam  Standard Deviation  December  2017       °c      0.944
# 9915    Viet Nam  Standard Deviation  December  2018       °c      0.944
# 9916    Viet Nam  Standard Deviation  December  2019       °c      0.944
# 9917    Viet Nam  Standard Deviation  December  2020       °c      0.944
# 9918    Viet Nam  Standard Deviation  December  2021       °c      0.944
#
#      TMP_Flag  TMP_Description
# 39          E  Estimated value
# 40          E  Estimated value
# 41          E  Estimated value
# 42          E  Estimated value
# 43          E  Estimated value
# ...       ...              ...
# 9914        E  Estimated value
# 9915        E  Estimated value
# 9916        E  Estimated value
# 9917        E  Estimated value
# 9918        E  Estimated value
#
# [2640 rows x 8 columns]

# %%
Land_Use_df= pd.read_csv("Land_Use.csv")
Land_Use_df.drop([ 'Domain','Domain Code', 'Area Code (M49)', 'Element Code', 'Item Code', 'Year Code', 'Note'],  axis=1,inplace=True)
Land_Use_df.rename(columns={'Item': 'Area_type','Value':'Area Value', 'Element': 'Land_Use_Element', 'Unit': 'Land_Use_Unit', 'Flag': 'Land_Use_Flag', 'Flag Description': 'Land_Use_Flag_Description'}, inplace=True)
Land_Use_df = Land_Use_df[Land_Use_df['Year'].between(2000, 2021)]
Land_Use_df = Land_Use_df[Land_Use_df['Area_type'].isin(['Agricultural land','Cropland','Arable land'])]
# print(Land_Use_df['Area_type'].unique())
Land_Use_df
# Out:
#             Area            Land_Use_Element          Area_type  Year  \
# 100   Bangladesh                        Area  Agricultural land  2000
# 101   Bangladesh                        Area  Agricultural land  2001
# 102   Bangladesh                        Area  Agricultural land  2002
# 103   Bangladesh                        Area  Agricultural land  2003
# 104   Bangladesh                        Area  Agricultural land  2004
# ...          ...                         ...                ...   ...
# 3294    Viet Nam  Share in Agricultural land        Arable land  2019
# 3295    Viet Nam                        Area        Arable land  2020
# 3296    Viet Nam  Share in Agricultural land        Arable land  2020
# 3297    Viet Nam                        Area        Arable land  2021
# 3298    Viet Nam  Share in Agricultural land        Arable land  2021
#
#      Land_Use_Unit  Area Value Land_Use_Flag Land_Use_Flag_Description
# 100        1000 ha     9400.00             I             Imputed value
# 101        1000 ha     9403.00             I             Imputed value
# 102        1000 ha     9353.00             I             Imputed value
# 103        1000 ha     9328.00             I             Imputed value
# 104        1000 ha     9323.00             I             Imputed value
# ...            ...         ...           ...                       ...
# 3294             %       54.76             E           Estimated value
# 3295       1000 ha     6787.00             A           Official figure
# 3296             %       54.91             E           Estimated value
# 3297       1000 ha     6787.00             I             Imputed value
# 3298             %       54.91             E           Estimated value
#
# [550 rows x 8 columns]

# %%
Emission_Total_df= pd.read_csv("Emission_Total.csv")
Emission_Total_df.drop(['Domain','Domain Code', 'Area Code (M49)', 'Element Code', 'Item Code (CPC)', 'Year Code',
       'Source Code', 'Source', 'Note'],  axis=1,inplace=True)
Emission_Total_df.rename(columns={'Element': 'Emissions','Value': "Emission_Value",'Item':'Crop_Name', 'Value': 'Emission_Total_Value',  'Unit': 'Emission_Total_Unit', 'Flag': 'Emission_Total_Flag', 'Flag Description': 'Emission_Total_Flag_Description'}, inplace=True)
Emission_Total_df = Emission_Total_df[Emission_Total_df['Year'].between(2000, 2021)]
Emission_Total_df= Emission_Total_df[Emission_Total_df['Emissions'].isin(['Crops total (Emissions N2O)' ,'Crop residues (N content)','Crops total (Emissions CH4)'])]
# print(Emission_Total_df['Emissions'].unique())
Emission_Total_df
# Out:
#             Area                    Emissions Crop_Name  Year  \
# 195   Bangladesh  Crops total (Emissions N2O)    Barley  2000
# 196   Bangladesh    Crop residues (N content)    Barley  2000
# 200   Bangladesh  Crops total (Emissions N2O)    Barley  2001
# 201   Bangladesh    Crop residues (N content)    Barley  2001
# 205   Bangladesh  Crops total (Emissions N2O)    Barley  2002
# ...          ...                          ...       ...   ...
# 7726    Viet Nam  Crops total (Emissions CH4)      Rice  2020
# 7727    Viet Nam    Crop residues (N content)      Rice  2020
# 7736    Viet Nam  Crops total (Emissions N2O)      Rice  2021
# 7737    Viet Nam  Crops total (Emissions CH4)      Rice  2021
# 7738    Viet Nam    Crop residues (N content)      Rice  2021
#
#      Emission_Total_Unit  Emission_Total_Value Emission_Total_Flag  \
# 195                   kt          1.700000e-03                   E
# 196                   kg          9.069507e+04                   E
# 200                   kt          1.400000e-03                   E
# 201                   kg          7.345336e+04                   E
# 205                   kt          1.000000e-03                   E
# ...                  ...                   ...                 ...
# 7726                  kt          1.285475e+03                   E
# 7727                  kg          4.691392e+08                   E
# 7736                  kt          9.470100e+00                   E
# 7737                  kt          1.285011e+03                   E
# 7738                  kg          4.775130e+08                   E
#
#      Emission_Total_Flag_Description
# 195                  Estimated value
# 196                  Estimated value
# 200                  Estimated value
# 201                  Estimated value
# 205                  Estimated value
# ...                              ...
# 7726                 Estimated value
# 7727                 Estimated value
# 7736                 Estimated value
# 7737                 Estimated value
# 7738                 Estimated value
#
# [880 rows x 8 columns]

# %%
Value_of_Agricultural_Production_df= pd.read_csv("Value_of_Agricultural_Production.csv")
Value_of_Agricultural_Production_df.drop(['Domain','Domain Code', 'Area Code (M49)', 'Element Code', 'Item Code (CPC)', 'Year Code'],  axis=1,inplace=True)
Value_of_Agricultural_Production_df.rename(columns={'Element': 'Production_Value_Type', 'Item': 'Crop_Name', 'Value': 'Production_Value_$', 'Unit': 'Prod_Output_Unit', 'Flag': 'Prod_Output_Flag', 'Flag Description': 'Prod_Output_Flag_Description'}, inplace=True)
Value_of_Agricultural_Production_df = Value_of_Agricultural_Production_df[Value_of_Agricultural_Production_df['Year'].between(2000, 2021)]
Value_of_Agricultural_Production_df= Value_of_Agricultural_Production_df[Value_of_Agricultural_Production_df['Production_Value_Type'].isin(['Gross Production Value (current thousand US$)'])]
# print(Value_of_Agricultural_Production_df['Production_Value_Type'].unique())
Value_of_Agricultural_Production_df
# Out:
#             Area                          Production_Value_Type   Crop_Name  \
# 124   Bangladesh  Gross Production Value (current thousand US$)      Barley
# 125   Bangladesh  Gross Production Value (current thousand US$)      Barley
# 342   Bangladesh  Gross Production Value (current thousand US$)        Rice
# 343   Bangladesh  Gross Production Value (current thousand US$)        Rice
# 344   Bangladesh  Gross Production Value (current thousand US$)        Rice
# ...          ...                                            ...         ...
# 3023    Viet Nam  Gross Production Value (current thousand US$)  Sugar cane
# 3024    Viet Nam  Gross Production Value (current thousand US$)  Sugar cane
# 3025    Viet Nam  Gross Production Value (current thousand US$)  Sugar cane
# 3026    Viet Nam  Gross Production Value (current thousand US$)  Sugar cane
# 3027    Viet Nam  Gross Production Value (current thousand US$)  Sugar cane
#
#       Year Prod_Output_Unit  Production_Value_$ Prod_Output_Flag  \
# 124   2006         1000 USD                 154                E
# 125   2007         1000 USD                 250                E
# 342   2000         1000 USD             4459731                E
# 343   2001         1000 USD             3918921                E
# 344   2002         1000 USD             4286101                E
# ...    ...              ...                 ...              ...
# 3023  2017         1000 USD              810942                E
# 3024  2018         1000 USD              713768                E
# 3025  2019         1000 USD              556230                E
# 3026  2020         1000 USD              401071                E
# 3027  2021         1000 USD              412302                E
#
#      Prod_Output_Flag_Description
# 124               Estimated value
# 125               Estimated value
# 342               Estimated value
# 343               Estimated value
# 344               Estimated value
# ...                           ...
# 3023              Estimated value
# 3024              Estimated value
# 3025              Estimated value
# 3026              Estimated value
# 3027              Estimated value
#
# [212 rows x 8 columns]

# %%
# merged_df=[[]]
# merged_df
# Out:
# [[]]

# %%
merged_df = pd.merge(Crop_Production_df, Emission_Total_df, on=['Area', 'Year','Crop_Name'], how='inner')
merged_df = pd.merge(merged_df,Value_of_Agricultural_Production_df, on=['Area', 'Year','Crop_Name'], how='inner')
merged_df = pd.merge(merged_df,Crop_Land_Nutrient_Balance_df, on=['Area', 'Year'], how='inner')
merged_df = pd.merge(merged_df, Temperature_Change_On_Land_df, on=['Area', 'Year'], how='inner')
merged_df = pd.merge(merged_df,Land_Use_df, on=['Area', 'Year'], how='inner')

# %%
merged_df
# Out:
#                Area       Prod_type   Crop_Name  Year Crop_Production_Unit  \
# 0        Bangladesh  Area harvested      Barley  2006                   ha
# 1        Bangladesh  Area harvested      Barley  2006                   ha
# 2        Bangladesh  Area harvested      Barley  2006                   ha
# 3        Bangladesh  Area harvested      Barley  2006                   ha
# 4        Bangladesh  Area harvested      Barley  2006                   ha
# ...             ...             ...         ...   ...                  ...
# 9694075    Viet Nam      Production  Sugar cane  2021                    t
# 9694076    Viet Nam      Production  Sugar cane  2021                    t
# 9694077    Viet Nam      Production  Sugar cane  2021                    t
# 9694078    Viet Nam      Production  Sugar cane  2021                    t
# 9694079    Viet Nam      Production  Sugar cane  2021                    t
#
#          Crop_Production_Value Crop_Production_Flag  \
# 0                       969.00                    A
# 1                       969.00                    A
# 2                       969.00                    A
# 3                       969.00                    A
# 4                       969.00                    A
# ...                        ...                  ...
# 9694075            10740873.28                    A
# 9694076            10740873.28                    A
# 9694077            10740873.28                    A
# 9694078            10740873.28                    A
# 9694079            10740873.28                    A
#
#         Crop_Production_Flag_Description                    Emissions  \
# 0                        Official figure  Crops total (Emissions N2O)
# 1                        Official figure  Crops total (Emissions N2O)
# 2                        Official figure  Crops total (Emissions N2O)
# 3                        Official figure  Crops total (Emissions N2O)
# 4                        Official figure  Crops total (Emissions N2O)
# ...                                  ...                          ...
# 9694075                  Official figure  Crops total (Emissions CH4)
# 9694076                  Official figure  Crops total (Emissions CH4)
# 9694077                  Official figure  Crops total (Emissions CH4)
# 9694078                  Official figure  Crops total (Emissions CH4)
# 9694079                  Official figure  Crops total (Emissions CH4)
#
#         Emission_Total_Unit  ...  TMP_Unit TMP_Value TMP_Flag  \
# 0                        kt  ...        °c     0.700        E
# 1                        kt  ...        °c     0.700        E
# 2                        kt  ...        °c     0.700        E
# 3                        kt  ...        °c     0.700        E
# 4                        kt  ...        °c     0.700        E
# ...                     ...  ...       ...       ...      ...
# 9694075                  kt  ...        °c     0.944        E
# 9694076                  kt  ...        °c     0.944        E
# 9694077                  kt  ...        °c     0.944        E
# 9694078                  kt  ...        °c     0.944        E
# 9694079                  kt  ...        °c     0.944        E
#
#          TMP_Description            Land_Use_Element          Area_type  \
# 0        Estimated value                        Area  Agricultural land
# 1        Estimated value                        Area           Cropland
# 2        Estimated value  Share in Agricultural land           Cropland
# 3        Estimated value                        Area        Arable land
# 4        Estimated value  Share in Agricultural land        Arable land
# ...                  ...                         ...                ...
# 9694075  Estimated value                        Area  Agricultural land
# 9694076  Estimated value                        Area           Cropland
# 9694077  Estimated value  Share in Agricultural land           Cropland
# 9694078  Estimated value                        Area        Arable land
# 9694079  Estimated value  Share in Agricultural land        Arable land
#
#         Land_Use_Unit Area Value Land_Use_Flag Land_Use_Flag_Description
# 0             1000 ha    9280.00             I             Imputed value
# 1             1000 ha    8680.00             A           Official figure
# 2                   %      93.53             E           Estimated value
# 3             1000 ha    7880.00             I             Imputed value
# 4                   %      84.91             E           Estimated value
# ...               ...        ...           ...                       ...
# 9694075       1000 ha   12360.00             I             Imputed value
# 9694076       1000 ha   11718.00             I             Imputed value
# 9694077             %      94.81             E           Estimated value
# 9694078       1000 ha    6787.00             I             Imputed value
# 9694079             %      54.91             E           Estimated value
#
# [9694080 rows x 36 columns]

# %%
merged_df.to_csv('Merged_data.csv', index=False)
